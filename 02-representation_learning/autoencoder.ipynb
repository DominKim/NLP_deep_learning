# %%
#### import numpy as np
import matplotlib.pyplot as plt
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="True"

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
from utils import load_mnist
from trainer import Trainer

# %%
from argparse import Namespace

config = {
    'train_ratio': .8,
    'batch_size': 256,
    'n_epochs': 50,
    'verbose': 1,
    'btl_size': 2
}

config = Namespace(**config)

print(config)
# Out:
# Namespace(batch_size=256, btl_size=2, n_epochs=50, train_ratio=0.8, verbose=1)

# %%
def show_image(x):
    if x.dim() == 1:
        x = x.view(int(x.size(0) ** .5), -1)
    
    plt.imshow(x, cmap='gray')
    plt.show()

# %%
train_x, train_y = load_mnist(flatten=True)
test_x, test_y = load_mnist(is_train=False, flatten=True)

train_cnt = int(train_x.size(0) * config.train_ratio)
valid_cnt = train_x.size(0) - train_cnt

# Shuffle dataset to split into train/valid set.
indices = torch.randperm(train_x.size(0))
train_x, valid_x = torch.index_select(
    train_x,
    dim=0,
    index=indices
).split([train_cnt, valid_cnt], dim=0)
train_y, valid_y = torch.index_select(
    train_y,
    dim=0,
    index=indices
).split([train_cnt, valid_cnt], dim=0)

print("Train:", train_x.shape, train_y.shape)
print("Valid:", valid_x.shape, valid_y.shape)
print("Test:", test_x.shape, test_y.shape)

# %%
from model import Autoencoder

# %%
model = Autoencoder(btl_size=config.btl_size)
optimizer = optim.Adam(model.parameters())
crit = nn.MSELoss()

trainer = Trainer(model, optimizer, crit)

# %%
trainer.train((train_x, train_x), (valid_x, valid_x), config)
# Out:
# Epoch(1/50): train_loss=7.1862e-02  valid_loss=4.9774e-02  lowest_loss=4.9774e-02
# Epoch(2/50): train_loss=4.8043e-02  valid_loss=4.6264e-02  lowest_loss=4.6264e-02
# Epoch(3/50): train_loss=4.5623e-02  valid_loss=4.4971e-02  lowest_loss=4.4971e-02
# Epoch(4/50): train_loss=4.4629e-02  valid_loss=4.4272e-02  lowest_loss=4.4272e-02
# Epoch(5/50): train_loss=4.3558e-02  valid_loss=4.1978e-02  lowest_loss=4.1978e-02
# Epoch(6/50): train_loss=4.2827e-02  valid_loss=4.2101e-02  lowest_loss=4.1978e-02
# Epoch(7/50): train_loss=4.2977e-02  valid_loss=4.2195e-02  lowest_loss=4.1978e-02
# Epoch(8/50): train_loss=4.2304e-02  valid_loss=4.4131e-02  lowest_loss=4.1978e-02
# Epoch(9/50): train_loss=4.1717e-02  valid_loss=4.1290e-02  lowest_loss=4.1290e-02
# Epoch(10/50): train_loss=4.2121e-02  valid_loss=4.1012e-02  lowest_loss=4.1012e-02
# Epoch(11/50): train_loss=4.1503e-02  valid_loss=4.0553e-02  lowest_loss=4.0553e-02
# Epoch(12/50): train_loss=4.1462e-02  valid_loss=4.0136e-02  lowest_loss=4.0136e-02
# Epoch(13/50): train_loss=4.1049e-02  valid_loss=3.9814e-02  lowest_loss=3.9814e-02
# Epoch(14/50): train_loss=4.0512e-02  valid_loss=3.9493e-02  lowest_loss=3.9493e-02
# Epoch(15/50): train_loss=4.0273e-02  valid_loss=3.9321e-02  lowest_loss=3.9321e-02
# Epoch(16/50): train_loss=4.0574e-02  valid_loss=3.9848e-02  lowest_loss=3.9321e-02
# Epoch(17/50): train_loss=4.0912e-02  valid_loss=3.9911e-02  lowest_loss=3.9321e-02
# Epoch(18/50): train_loss=4.0109e-02  valid_loss=3.8834e-02  lowest_loss=3.8834e-02
# Epoch(19/50): train_loss=4.0609e-02  valid_loss=4.0156e-02  lowest_loss=3.8834e-02
# Epoch(20/50): train_loss=4.0367e-02  valid_loss=3.8330e-02  lowest_loss=3.8330e-02
# Epoch(21/50): train_loss=3.9593e-02  valid_loss=3.8168e-02  lowest_loss=3.8168e-02
# Epoch(22/50): train_loss=3.9123e-02  valid_loss=3.7617e-02  lowest_loss=3.7617e-02
# Epoch(23/50): train_loss=3.8818e-02  valid_loss=3.9045e-02  lowest_loss=3.7617e-02
# Epoch(24/50): train_loss=3.8973e-02  valid_loss=3.7767e-02  lowest_loss=3.7617e-02
# Epoch(25/50): train_loss=3.9246e-02  valid_loss=3.8313e-02  lowest_loss=3.7617e-02
# Epoch(26/50): train_loss=3.8881e-02  valid_loss=3.7571e-02  lowest_loss=3.7571e-02
# Epoch(27/50): train_loss=3.8797e-02  valid_loss=3.7632e-02  lowest_loss=3.7571e-02
# Epoch(28/50): train_loss=3.8780e-02  valid_loss=3.7866e-02  lowest_loss=3.7571e-02
# Epoch(29/50): train_loss=3.8793e-02  valid_loss=3.8176e-02  lowest_loss=3.7571e-02
# Epoch(30/50): train_loss=3.8653e-02  valid_loss=3.7624e-02  lowest_loss=3.7571e-02
# Epoch(31/50): train_loss=3.8652e-02  valid_loss=3.7685e-02  lowest_loss=3.7571e-02
# Epoch(32/50): train_loss=3.8842e-02  valid_loss=3.7162e-02  lowest_loss=3.7162e-02
# Epoch(33/50): train_loss=3.8131e-02  valid_loss=3.6683e-02  lowest_loss=3.6683e-02
# Epoch(34/50): train_loss=3.8371e-02  valid_loss=3.8187e-02  lowest_loss=3.6683e-02
# Epoch(35/50): train_loss=3.8954e-02  valid_loss=3.7677e-02  lowest_loss=3.6683e-02
# Epoch(36/50): train_loss=3.8456e-02  valid_loss=3.7032e-02  lowest_loss=3.6683e-02
# Epoch(37/50): train_loss=3.8148e-02  valid_loss=3.6820e-02  lowest_loss=3.6683e-02
# Epoch(38/50): train_loss=3.8095e-02  valid_loss=3.7503e-02  lowest_loss=3.6683e-02
# Epoch(39/50): train_loss=3.8690e-02  valid_loss=3.9519e-02  lowest_loss=3.6683e-02
# Epoch(40/50): train_loss=3.9873e-02  valid_loss=3.7819e-02  lowest_loss=3.6683e-02
# Epoch(41/50): train_loss=3.8562e-02  valid_loss=3.7025e-02  lowest_loss=3.6683e-02
# Epoch(42/50): train_loss=3.8096e-02  valid_loss=3.6883e-02  lowest_loss=3.6683e-02
# Epoch(43/50): train_loss=3.7814e-02  valid_loss=3.6781e-02  lowest_loss=3.6683e-02
# Epoch(44/50): train_loss=3.7460e-02  valid_loss=3.6482e-02  lowest_loss=3.6482e-02
# Epoch(45/50): train_loss=3.7575e-02  valid_loss=3.7290e-02  lowest_loss=3.6482e-02
# Epoch(46/50): train_loss=3.7986e-02  valid_loss=3.6965e-02  lowest_loss=3.6482e-02
# Epoch(47/50): train_loss=3.7483e-02  valid_loss=3.6268e-02  lowest_loss=3.6268e-02
# Epoch(48/50): train_loss=3.7421e-02  valid_loss=3.6559e-02  lowest_loss=3.6268e-02
# Epoch(49/50): train_loss=3.7368e-02  valid_loss=3.8393e-02  lowest_loss=3.6268e-02
# Epoch(50/50): train_loss=3.7398e-02  valid_loss=3.6689e-02  lowest_loss=3.6268e-02

# %% [markdown]
# ## Test

# %%
with torch.no_grad():
    import random

    index = int(random.random() * test_x.size(0))
    
    # test_x[index] = (784,)
    recon = model(test_x[index].view(1, -1)).squeeze()

    show_image(test_x[index])
    show_image(recon)

# %% [markdown]
# ## Latent Space

# %%
if config.btl_size == 2:
    color_map = [
        'brown', 'red', 'orange', 'yellow', 'green',
        'blue', 'navy', 'purple', 'gray', 'black',
    ]
    
    plt.figure(figsize=(20, 10))
    with torch.no_grad():
        latents = model.encoder(test_x[:1000])
        
        for i in range(10):
            target_latents = latents[test_y[:1000] == i]
            target_y = test_y[:1000][test_y[:1000] == i]
            plt.scatter(target_latents[:, 0],
                        target_latents[:, 1],
                        marker='o',
                        color=color_map[i],
                        label=i)
        
        plt.legend()
        plt.grid(axis='both')
        plt.show()

# %%
if config.btl_size == 2:
    min_range, max_range = -1., 2.
    n = 20
    step = (max_range - min_range) / float(n)
    
    with torch.no_grad():
        lines = []

        for v1 in np.arange(min_range, max_range, step):
            z = torch.stack([
                torch.FloatTensor([v1] * n),
                torch.FloatTensor([v2 for v2 in np.arange(min_range,
                                                          max_range, step)]),
            ], dim=-1)
            
            # clamp 어떤 크기로 쳐내는거
            line = torch.clamp(model.decoder(z).view(n, 28, 28), 0, 1)
            line = torch.cat([line[i] for i in range(n - 1, 0, -1)], dim=0)
            lines += [line]
            
        lines = torch.cat(lines, dim=-1)
        plt.figure(figsize=(20, 20))
        show_image(lines)
